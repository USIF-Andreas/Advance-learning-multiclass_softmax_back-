# %% [markdown]
# <a href="https://colab.research.google.com/github/USIF-Andreas/Advance-learning-multiclass_softmax_back-/blob/main/softmax_first.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
np.set_printoptions(precision=2)

# %%
import math
def my_softmax(z):
    """ Softmax converts a vector of values to a probability distribution.
    Args:
      z (ndarray (N,))  : input data, N features
    Returns:
      a (ndarray (N,))  : softmax of z
    """
    ### START CODE HERE ###
    a=[]
    sum=0
    for i in z:
        sum+=math.e**i

    for i in z:
        a.append(math.e**i/sum)
    return a

# %%
z = np.array([1., 2., 3., 4.])
a = my_softmax(z)
atf = tf.nn.softmax(z)
print(f"my_softmax(z):         {a}")
print(f"tensorflow softmax(z): {atf}")
# Out:
# my_softmax(z):         [np.float64(0.03205860328008499), np.float64(0.08714431874203257), np.float64(0.23688281808991013), np.float64(0.6439142598879722)]
# tensorflow softmax(z): [0.03 0.09 0.24 0.64]

# %%
import pandas as pd
df=pd.read_csv('data.csv')
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
y=df['Medical Condition']
X=df.drop('Medical Condition',axis=1)

# %%
X=X.drop('Name',axis=1)

# %%
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# Encode gender and blood type
label_encoders = {}
categorical_cols = ['Gender', 'Blood Type','Test Results','Admission Type','Admission Type','Medication'	]
for col in categorical_cols:
    le = LabelEncoder()
    X[col] = le.fit_transform(X[col])
    label_encoders[col] = le  # Store the encoder for later use if needed


# Scale billing amount
scaler = MinMaxScaler()
X['Billing Amount'] = scaler.fit_transform(X[['Billing Amount']])

# %%
le = LabelEncoder()
y = le.fit_transform(y)
label_encoders['Medical Condition'] = le  # Store the encoder for later use if needed

# %%
X['Medical Condition']=y
y=X['Test Results']
X=X.drop('Test Results',axis=1)

# %%
X.head()
# Out:
#    Age  Gender  Blood Type  Billing Amount  Room Number  Admission Type  \
# 0   30       1           5        0.380933        328.0               2
# 1   62       1           0        0.650904        265.0               1
# 2   76       0           1        0.547053        205.0               1
# 3   28       0           6        0.728798        450.0               0
# 4   43       0           2        0.296622        458.0               2
#
#    Medication  Medical Condition
# 0           3                  2
# 1           1                  5
# 2           0                  5
# 3           1                  3
# 4           4                  2

# %%
y.unique()
# Out:
# array([2, 1, 0, 3])

# %%
tf.random.set_seed(1234) # for consistent results
model = Sequential(
    [
        ### START CODE HERE ###
        Dense(units=25,activation='relu'),
        Dense(units=15,activation='relu'),
        Dense(units=4,activation='linear')


        ### END CODE HERE ###
    ], name = "my_model"
)
model.compile(
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

model.fit(
    X,y,
    epochs=5
)
# Out:
# Epoch 1/5
# 1516/1516 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: nan
# Epoch 2/5
# 1516/1516 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: nan
# Epoch 3/5
# 1516/1516 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: nan
# Epoch 4/5
# 1516/1516 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: nan
# Epoch 5/5
# 1516/1516 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: nan

# %%
model.summary()
# Out:
# Model: "my_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 25)                  │             225 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 15)                  │             390 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 4)                   │              64 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,039 (7.97 KB)
#  Trainable params: 679 (2.65 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,360 (5.32 KB)
